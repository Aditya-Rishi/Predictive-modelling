# %% [markdown]
# ## Problem 1: Linear Regression
#
#
# You are hired by a company Gem Stones co ltd, which is a cubic zirconia manufacturer. You are provided with the dataset containing the prices and other attributes of almost 27,000 cubic zirconia (which is an inexpensive diamond alternative with many of the same qualities as a diamond). The company is earning different profits on different prize slots. You have to help the company in predicting the price for the stone on the bases of the details given in the dataset so it can distinguish between higher profitable stones and lower profitable stones so as to have better profit share. Also, provide them with the best 5 attributes that are most important.

# %% [markdown]
# ### Import important libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.style
plt.style.use('seaborn')
import statsmodels.api as sm
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# ### 1.1. Read the data and do exploratory data analysis. Describe the data briefly. (Check the null values, data types, and shape, and do EDA). Perform univariate and bivariate Analysis.

# %%
df = pd.read_csv("cubic_zirconia.csv")

# %%
df.shape
# Out:
# (26967, 11)

# %%
df.head(10)
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table     x     y     z  \
# 0           1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66
# 1           2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70
# 2           3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78
# 3           4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96
# 4           5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65
# 5           6   1.02      Ideal     D     VS2   61.5   56.0  6.46  6.49  3.99
# 6           7   1.01       Good     H     SI1   63.7   60.0  6.35  6.30  4.03
# 7           8   0.50    Premium     E     SI1   61.5   62.0  5.09  5.06  3.12
# 8           9   1.21       Good     H     SI1   63.8   64.0  6.72  6.63  4.26
# 9          10   0.35      Ideal     F     VS2   60.5   57.0  4.52  4.60  2.76
#
#    price
# 0    499
# 1    984
# 2   6289
# 3   1082
# 4    779
# 5   9502
# 6   4836
# 7   1415
# 8   5407
# 9    706

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26967 entries, 0 to 26966
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  26967 non-null  int64
#  1   carat       26967 non-null  float64
#  2   cut         26967 non-null  object
#  3   color       26967 non-null  object
#  4   clarity     26967 non-null  object
#  5   depth       26270 non-null  float64
#  6   table       26967 non-null  float64
#  7   x           26967 non-null  float64
#  8   y           26967 non-null  float64
#  9   z           26967 non-null  float64
#  10  price       26967 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 2.3+ MB

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
dups = df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
# Out:
# Number of duplicate rows = 34

# %%
df.describe(include="all").T
# Out:
#          count unique    top   freq      mean       std   min   25%   50%  \
# carat    26967    NaN    NaN    NaN  0.798375  0.477745   0.2   0.4   0.7
# cut      26967      5  Ideal  10816       NaN       NaN   NaN   NaN   NaN
# color    26967      7      G   5661       NaN       NaN   NaN   NaN   NaN
# clarity  26967      8    SI1   6571       NaN       NaN   NaN   NaN   NaN
# depth    26270    NaN    NaN    NaN   61.7451   1.41286  50.8    61  61.8
# table    26967    NaN    NaN    NaN   57.4561   2.23207    49    56    57
# x        26967    NaN    NaN    NaN   5.72985   1.12852     0  4.71  5.69
# y        26967    NaN    NaN    NaN   5.73357   1.16606     0  4.71  5.71
# z        26967    NaN    NaN    NaN   3.53806  0.720624     0   2.9  3.52
# price    26967    NaN    NaN    NaN   3939.52   4024.86   326   945  2375
#
#           75%    max
# carat    1.05    4.5
# cut       NaN    NaN
# color     NaN    NaN
# clarity   NaN    NaN
# depth    62.5   73.6
# table      59     79
# x        6.55  10.23
# y        6.54   58.9
# z        4.04   31.8
# price    5360  18818

# %%
colors = ['m','c','b','g','y']
df.cut.value_counts(normalize=True).plot(kind='pie', autopct='%1.0f%%', colors = colors)
plt.title('Proportion of Cut');

# %%
colors = ['c','b','g','y','r','m','w']
df.color.value_counts(normalize=True).plot(kind='pie', autopct='%1.0f%%', colors = colors)
plt.title('Proportion of Color');

# %%
colors = ['m','c','b','g','y','r','w','k']
df.clarity.value_counts(normalize=True).plot(kind='pie', autopct='%1.0f%%', colors = colors)
plt.title('Proportion of Clarity');

# %%
for column in df.columns:
    if df[column].dtype == 'object':
        print(column.upper(),': ',df[column].nunique())
        print(df[column].value_counts().sort_values())
        print('\n');
# Out:
# CUT :  5
# Fair           781
# Good          2441
# Very Good     6030
# Premium       6899
# Ideal        10816
# Name: cut, dtype: int64
#
#
# COLOR :  7
# J    1443
# I    2771
# D    3344
# H    4102
# F    4729
# E    4917
# G    5661
# Name: color, dtype: int64
#
#
# CLARITY :  8
# I1       365
# IF       894
# VVS1    1839
# VVS2    2531
# VS1     4093
# SI2     4575
# VS2     6099
# SI1     6571
# Name: clarity, dtype: int64

# %%
# EDA for categorical columns 'CUT'.
sns.catplot('cut', data=df, kind='count',aspect=2.5);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot(x='cut', y='price', kind='box', data=df, aspect=2.5);

# %% [markdown]
# Observation on 'Cut': The premium-cut diamonds are the most expensive, followed by those with very good cut.

# %%
# EDA for categorical columns 'Color'.
sns.catplot('color', kind='count', data=df, aspect=2.5);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot(x='color', y='price', data=df, aspect =2.5, kind='box');

# %% [markdown]
# Observation on 'Color': The j or worst-color diamonds are the most expensive, followed by I, suggesting some industrial usage.

# %%
# EDA for categorical columns 'Clarity'.
sns.catplot('clarity', data=df, kind='count',aspect=2.5);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot(x='clarity', y='price', data=df, aspect =2.5, kind='box');

# %% [markdown]
# Observation on 'clarity': The diamonds with VS1 & VS2 clarity are the most expensive.

# %%
pd.crosstab(df['cut'], df['color'])
# Out:
# color         D     E     F     G     H     I    J
# cut
# Fair         74   100   148   147   150    94   68
# Good        311   491   454   419   352   253  161
# Ideal      1409  1966  1893  2470  1552  1073  453
# Premium     808  1174  1167  1471  1161   711  407
# Very Good   742  1186  1067  1154   887   640  354

# %%
pd.crosstab(df['cut'], df['color']).plot(kind = 'bar', stacked = True);

# %%
pd.crosstab(df['cut'], df['clarity'])
# Out:
# clarity     I1   IF   SI1   SI2   VS1   VS2  VVS1  VVS2
# cut
# Fair        89    4   193   225    93   129    10    38
# Good        51   30   765   530   331   491   100   143
# Ideal       74  613  2150  1324  1784  2528  1036  1307
# Premium    108  115  1809  1449   998  1697   307   416
# Very Good   43  132  1654  1047   887  1254   386   627

# %%
pd.crosstab(df['cut'], df['clarity']).plot(kind = 'bar', stacked = True);

# %% [markdown]
# ### Encode the data (having string values) for Modelling. Data Split: Split the data into train and test (70:30). Apply Linear regression. Performance Metrics: Check the performance of Predictions on Train and Test sets using Rsquare, RMSE.

# %%
#df = pd.get_dummies(df, columns=['cut','color','clarity'],drop_first=True)
# Doing ordinal encoding for these categoric variables as these are ordinal quality attributes 

cut_dict = {'Fair': 0,
            'Good': 1,
            'Very Good': 2,
            'Premium': 3,
            'Ideal':4
           }
df.cut = df.cut.map(cut_dict)
df.cut.astype(str).astype(int)

color_dict = {'D': 6,'E': 5,'F': 4,'G': 3,'H': 2,'I': 1,'J': 0}
df.color = df.color.map(color_dict)
df.color.astype(str).astype(int)

clarity_dict = {'FL': 10,
               'IF': 9,
               'VVS1': 8,
               'VVS2': 7,
               'VS1': 6,
               'VS2': 5,
               'SI1': 4, 
               'SI2': 3, 
               'I1': 2, 
               'I2': 1, 
               'I3': 0}
df.clarity = df.clarity.map(clarity_dict)
df.clarity.astype(str).astype(int)
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26967 entries, 0 to 26966
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    26967 non-null  float64
#  1   cut      26967 non-null  int64
#  2   color    26967 non-null  int64
#  3   clarity  26967 non-null  int64
#  4   depth    26270 non-null  float64
#  5   table    26967 non-null  float64
#  6   x        26967 non-null  float64
#  7   y        26967 non-null  float64
#  8   z        26967 non-null  float64
#  9   price    26967 non-null  int64
# dtypes: float64(6), int64(4)
# memory usage: 2.1 MB

# %%
df.describe(include="all").T
# Out:
#            count         mean          std    min     25%      50%      75%  \
# carat    26967.0     0.798375     0.477745    0.2    0.40     0.70     1.05
# cut      26967.0     2.909556     1.113229    0.0    2.00     3.00     4.00
# color    26967.0     3.393889     1.705992    0.0    2.00     3.00     5.00
# clarity  26967.0     5.053102     1.647042    2.0    4.00     5.00     6.00
# depth    26270.0    61.745147     1.412860   50.8   61.00    61.80    62.50
# table    26967.0    57.456080     2.232068   49.0   56.00    57.00    59.00
# x        26967.0     5.729854     1.128516    0.0    4.71     5.69     6.55
# y        26967.0     5.733569     1.166058    0.0    4.71     5.71     6.54
# z        26967.0     3.538057     0.720624    0.0    2.90     3.52     4.04
# price    26967.0  3939.518115  4024.864666  326.0  945.00  2375.00  5360.00
#
#               max
# carat        4.50
# cut          4.00
# color        6.00
# clarity      9.00
# depth       73.60
# table       79.00
# x           10.23
# y           58.90
# z           31.80
# price    18818.00

# %% [markdown]
# ### 1.2 Impute null values if present, also check for the values which are equal to zero. Do they have any meaning or do we need to change them or drop them? Do you think scaling is necessary in this case?

# %%
df.isnull().sum()
# Out:
# carat        0
# cut          0
# color        0
# clarity      0
# depth      697
# table        0
# x            0
# y            0
# z            0
# price        0
# dtype: int64

# %%
df['depth'] = df['depth'].fillna(df['depth'].mean())          
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
dups = df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
# Out:
# Number of duplicate rows = 34

# %%
df.describe().T
# Out:
#            count         mean          std    min     25%      50%      75%  \
# carat    26967.0     0.798375     0.477745    0.2    0.40     0.70     1.05
# cut      26967.0     2.909556     1.113229    0.0    2.00     3.00     4.00
# color    26967.0     3.393889     1.705992    0.0    2.00     3.00     5.00
# clarity  26967.0     5.053102     1.647042    2.0    4.00     5.00     6.00
# depth    26967.0    61.745147     1.394481   50.8   61.10    61.80    62.50
# table    26967.0    57.456080     2.232068   49.0   56.00    57.00    59.00
# x        26967.0     5.729854     1.128516    0.0    4.71     5.69     6.55
# y        26967.0     5.733569     1.166058    0.0    4.71     5.71     6.54
# z        26967.0     3.538057     0.720624    0.0    2.90     3.52     4.04
# price    26967.0  3939.518115  4024.864666  326.0  945.00  2375.00  5360.00
#
#               max
# carat        4.50
# cut          4.00
# color        6.00
# clarity      9.00
# depth       73.60
# table       79.00
# x           10.23
# y           58.90
# z           31.80
# price    18818.00

# %%
print('Shape before replacing zeros and removing all missing values: ',df.shape)
# Replace 0 in x,y & z to Nan and remove all missing values
df.x = df.x.replace(to_replace = 0 , value =np.nan)
df.y = df.x.replace(to_replace = 0 , value =np.nan)
df.z = df.x.replace(to_replace = 0 , value =np.nan)
df.dropna(inplace=True)
print('Shape after replacing zeros and removing all missing values: ',df.shape)
# Out:
# Shape before replacing zeros and removing all missing values:  (26967, 10)
# Shape after replacing zeros and removing all missing values:  (26964, 10)

# %%
dups = df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
# Out:
# Number of duplicate rows = 47

# %%
print('Shape before removing duplicate values',df.shape)
df.drop_duplicates(inplace=True) 
print('Shape after removing duplicate values',df.shape)
# Out:
# Shape before removing duplicate values (26964, 10)
# Shape after removing duplicate values (26917, 10)

# %%
ax = sns.pairplot(df[['carat','depth','table','x','y','z','price']], diag_kind='kde')
for i, j in zip(*np.triu_indices_from(ax.axes, 1)):
    ax.axes[i, j].set_visible(False)

# %%
plt.subplots(figsize=(10,8))
ax = sns.heatmap(df[['carat','depth','table','x','y','z','price']].corr(), cmap='ocean', annot=True)
bottom, top = ax.get_ylim()
ax.set_ylim (bottom + 0.5, top - 0.5);

# %%
plt.figure(figsize=(10,2))
plt.title('Price With Outliers',fontsize=16)
sns.boxplot(df['price'] , orient = "h" , color = 'c');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,5))
plt.title('Distribution of Price',fontsize=16)
sns.distplot(df['price'], color = 'c' );
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,2))
plt.title('Carat With Outliers',fontsize=12)
sns.boxplot(df['carat'] , orient = "h" , color = 'c');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,5))
plt.title('Distribution of Carat',fontsize=12)
sns.distplot(df['carat'], color = 'c' );
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,2))
plt.title('Color With Outliers',fontsize=12)
sns.boxplot(df['color'] , orient = "h" , color = 'c');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,5))
plt.title('Distribution of Color',fontsize=12)
sns.distplot(df['color'], color = 'c' );
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,2))
plt.title('Clarity With Outliers',fontsize=12)
sns.boxplot(df['clarity'] , orient = "h" , color = 'c');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,5))
plt.title('Distribution of Clarity',fontsize=12)
sns.distplot(df['clarity'], color = 'c' );
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,2))
plt.title('Table With Outliers',fontsize=12)
sns.boxplot(df['table'] , orient = "h" , color = 'c');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,5))
plt.title('Distribution of Table',fontsize=12)
sns.distplot(df['table'], color = 'c' );
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,2))
plt.title('Cut With Outliers',fontsize=12)
sns.boxplot(df['cut'] , orient = "h" , color = 'c');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,5))
plt.title('Distribution of cut',fontsize=12)
sns.distplot(df['cut'], color = 'c' );
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,2))
plt.title('x With Outliers',fontsize=12)
sns.boxplot(df['x'] , orient = "h" , color = 'c');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,5))
plt.title('Distribution of x',fontsize=12)
sns.distplot(df['x'], color = 'c' );
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,2))
plt.title('y With Outliers',fontsize=12)
sns.boxplot(df['y'] , orient = "h" , color = 'c');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,5))
plt.title('Distribution of y',fontsize=12)
sns.distplot(df['y'], color = 'c' );
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,2))
plt.title('z With Outliers',fontsize=12)
sns.boxplot(df['z'] , orient = "h" , color = 'c');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,5))
plt.title('Distribution of z',fontsize=12)
sns.distplot(df['z'], color = 'c' );
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,2))
plt.title('depth With Outliers',fontsize=12)
sns.boxplot(df['depth'] , orient = "h" , color = 'c');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,5))
plt.title('Distribution of depth',fontsize=12)
sns.distplot(df['depth'], color = 'c' );
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.hist(figsize=(20,30));

# %%
df[['price', 'cut']].groupby(['cut']).agg(['min', 'mean', 'max']).style.background_gradient(cmap='ocean')
# Out:
# <style  type="text/css" >
# #T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow0_col0,#T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow0_col1,#T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow2_col2{
#             background-color:  #ffffff;
#             color:  #000000;
#         }#T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow0_col2,#T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow3_col0,#T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow4_col0,#T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow4_col1{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow1_col0{
#             background-color:  #003035;
#             color:  #f1f1f1;
#         }#T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow1_col1{
#             background-color:  #00226c;
#             color:  #f1f1f1;
#         }#T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow1_col2{
#             background-color:  #00518b;
#             color:  #f1f1f1;
#         }#T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow2_col0{
#             background-color:  #00273b;
#             color:  #f1f1f1;
#         }#T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow2_col1{
#             background-color:  #004684;
#             color:  #f1f1f1;
#         }#T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow3_col1{
#             background-color:  #f3f9fb;
#             color:  #000000;
#         }#T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow3_col2{
#             background-color:  #b7dbe7;
#             color:  #000000;
#         }#T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow4_col2{
#             background-color:  #d5eaf1;
#             color:  #000000;
#         }</style><table id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=3>price</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >min</th>        <th class="col_heading level1 col1" >mean</th>        <th class="col_heading level1 col2" >max</th>    </tr>    <tr>        <th class="index_name level0" >cut</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139flevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow0_col0" class="data row0 col0" >369</td>
#                         <td id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow0_col1" class="data row0 col1" >4565.768935</td>
#                         <td id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow0_col2" class="data row0 col2" >18574</td>
#             </tr>
#             <tr>
#                         <th id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139flevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow1_col0" class="data row1 col0" >335</td>
#                         <td id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow1_col1" class="data row1 col1" >3927.074774</td>
#                         <td id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow1_col2" class="data row1 col2" >18707</td>
#             </tr>
#             <tr>
#                         <th id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139flevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow2_col0" class="data row2 col0" >336</td>
#                         <td id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow2_col1" class="data row2 col1" >4032.581812</td>
#                         <td id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow2_col2" class="data row2 col2" >18818</td>
#             </tr>
#             <tr>
#                         <th id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139flevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow3_col0" class="data row3 col0" >326</td>
#                         <td id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow3_col1" class="data row3 col1" >4545.127814</td>
#                         <td id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow3_col2" class="data row3 col2" >18795</td>
#             </tr>
#             <tr>
#                         <th id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139flevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow4_col0" class="data row4 col0" >326</td>
#                         <td id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow4_col1" class="data row4 col1" >3457.579264</td>
#                         <td id="T_f71f528d_f166_11eb_9eb7_d3fe1e01139frow4_col2" class="data row4 col2" >18804</td>
#             </tr>
#     </tbody></table>

# %%
df[['price', 'color']].groupby(['color']).agg(['min', 'mean', 'max']).style.background_gradient(cmap='ocean')
# Out:
# <style  type="text/css" >
# #T_f8e3309d_f166_11eb_954b_d3fe1e01139frow0_col0{
#             background-color:  #001e41;
#             color:  #f1f1f1;
#         }#T_f8e3309d_f166_11eb_954b_d3fe1e01139frow0_col1,#T_f8e3309d_f166_11eb_954b_d3fe1e01139frow3_col0,#T_f8e3309d_f166_11eb_954b_d3fe1e01139frow3_col2{
#             background-color:  #ffffff;
#             color:  #000000;
#         }#T_f8e3309d_f166_11eb_954b_d3fe1e01139frow0_col2{
#             background-color:  #006699;
#             color:  #f1f1f1;
#         }#T_f8e3309d_f166_11eb_954b_d3fe1e01139frow1_col0{
#             background-color:  #001249;
#             color:  #f1f1f1;
#         }#T_f8e3309d_f166_11eb_954b_d3fe1e01139frow1_col1,#T_f8e3309d_f166_11eb_954b_d3fe1e01139frow4_col2{
#             background-color:  #badce8;
#             color:  #000000;
#         }#T_f8e3309d_f166_11eb_954b_d3fe1e01139frow1_col2,#T_f8e3309d_f166_11eb_954b_d3fe1e01139frow2_col2{
#             background-color:  #c3e1eb;
#             color:  #000000;
#         }#T_f8e3309d_f166_11eb_954b_d3fe1e01139frow2_col0{
#             background-color:  #000850;
#             color:  #f1f1f1;
#         }#T_f8e3309d_f166_11eb_954b_d3fe1e01139frow2_col1{
#             background-color:  #006f9f;
#             color:  #f1f1f1;
#         }#T_f8e3309d_f166_11eb_954b_d3fe1e01139frow3_col1{
#             background-color:  #001e69;
#             color:  #f1f1f1;
#         }#T_f8e3309d_f166_11eb_954b_d3fe1e01139frow4_col0,#T_f8e3309d_f166_11eb_954b_d3fe1e01139frow6_col0{
#             background-color:  #a8d3e2;
#             color:  #000000;
#         }#T_f8e3309d_f166_11eb_954b_d3fe1e01139frow4_col1{
#             background-color:  #001547;
#             color:  #f1f1f1;
#         }#T_f8e3309d_f166_11eb_954b_d3fe1e01139frow5_col0,#T_f8e3309d_f166_11eb_954b_d3fe1e01139frow5_col1,#T_f8e3309d_f166_11eb_954b_d3fe1e01139frow6_col2{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_f8e3309d_f166_11eb_954b_d3fe1e01139frow5_col2{
#             background-color:  #1b8db3;
#             color:  #000000;
#         }#T_f8e3309d_f166_11eb_954b_d3fe1e01139frow6_col1{
#             background-color:  #006e0c;
#             color:  #f1f1f1;
#         }</style><table id="T_f8e3309d_f166_11eb_954b_d3fe1e01139f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=3>price</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >min</th>        <th class="col_heading level1 col1" >mean</th>        <th class="col_heading level1 col2" >max</th>    </tr>    <tr>        <th class="index_name level0" >color</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f8e3309d_f166_11eb_954b_d3fe1e01139flevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow0_col0" class="data row0 col0" >335</td>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow0_col1" class="data row0 col1" >5329.706250</td>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow0_col2" class="data row0 col2" >18701</td>
#             </tr>
#             <tr>
#                         <th id="T_f8e3309d_f166_11eb_954b_d3fe1e01139flevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow1_col0" class="data row1 col0" >336</td>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow1_col1" class="data row1 col1" >5124.816637</td>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow1_col2" class="data row1 col2" >18795</td>
#             </tr>
#             <tr>
#                         <th id="T_f8e3309d_f166_11eb_954b_d3fe1e01139flevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow2_col0" class="data row2 col0" >337</td>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow2_col1" class="data row2 col1" >4478.887152</td>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow2_col2" class="data row2 col2" >18795</td>
#             </tr>
#             <tr>
#                         <th id="T_f8e3309d_f166_11eb_954b_d3fe1e01139flevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow3_col0" class="data row3 col0" >361</td>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow3_col1" class="data row3 col1" >4008.067493</td>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow3_col2" class="data row3 col2" >18818</td>
#             </tr>
#             <tr>
#                         <th id="T_f8e3309d_f166_11eb_954b_d3fe1e01139flevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow4_col0" class="data row4 col0" >357</td>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow4_col1" class="data row4 col1" >3701.517585</td>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow4_col2" class="data row4 col2" >18791</td>
#             </tr>
#             <tr>
#                         <th id="T_f8e3309d_f166_11eb_954b_d3fe1e01139flevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow5_col0" class="data row5 col0" >326</td>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow5_col1" class="data row5 col1" >3074.382706</td>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow5_col2" class="data row5 col2" >18731</td>
#             </tr>
#             <tr>
#                         <th id="T_f8e3309d_f166_11eb_954b_d3fe1e01139flevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow6_col0" class="data row6 col0" >357</td>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow6_col1" class="data row6 col1" >3186.841222</td>
#                         <td id="T_f8e3309d_f166_11eb_954b_d3fe1e01139frow6_col2" class="data row6 col2" >18526</td>
#             </tr>
#     </tbody></table>

# %%
df[['price', 'clarity']].groupby(['clarity']).agg(['min', 'mean', 'max']).style.background_gradient(cmap='ocean')
# Out:
# <style  type="text/css" >
# #T_fb1269e8_f166_11eb_864b_d3fe1e01139frow0_col0{
#             background-color:  #002a71;
#             color:  #f1f1f1;
#         }#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow0_col1{
#             background-color:  #00518b;
#             color:  #f1f1f1;
#         }#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow0_col2,#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow5_col0,#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow6_col0{
#             background-color:  #00273b;
#             color:  #f1f1f1;
#         }#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow1_col0,#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow2_col0,#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow6_col1,#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow6_col2{
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow1_col1,#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow2_col2,#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow7_col0{
#             background-color:  #ffffff;
#             color:  #000000;
#         }#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow1_col2{
#             background-color:  #e4f2f6;
#             color:  #000000;
#         }#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow2_col1{
#             background-color:  #005e94;
#             color:  #f1f1f1;
#         }#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow3_col0{
#             background-color:  #2a94b8;
#             color:  #000000;
#         }#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow3_col1{
#             background-color:  #005890;
#             color:  #f1f1f1;
#         }#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow3_col2{
#             background-color:  #c9e4ed;
#             color:  #000000;
#         }#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow4_col0{
#             background-color:  #001547;
#             color:  #f1f1f1;
#         }#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow4_col1{
#             background-color:  #004684;
#             color:  #f1f1f1;
#         }#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow4_col2{
#             background-color:  #d2e8f0;
#             color:  #000000;
#         }#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow5_col1{
#             background-color:  #000f4b;
#             color:  #f1f1f1;
#         }#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow5_col2{
#             background-color:  #3399bb;
#             color:  #000000;
#         }#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow7_col1{
#             background-color:  #005d17;
#             color:  #f1f1f1;
#         }#T_fb1269e8_f166_11eb_864b_d3fe1e01139frow7_col2{
#             background-color:  #001249;
#             color:  #f1f1f1;
#         }</style><table id="T_fb1269e8_f166_11eb_864b_d3fe1e01139f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=3>price</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >min</th>        <th class="col_heading level1 col1" >mean</th>        <th class="col_heading level1 col2" >max</th>    </tr>    <tr>        <th class="index_name level0" >clarity</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fb1269e8_f166_11eb_864b_d3fe1e01139flevel0_row0" class="row_heading level0 row0" >2</th>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow0_col0" class="data row0 col0" >345</td>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow0_col1" class="data row0 col1" >3908.750000</td>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow0_col2" class="data row0 col2" >18531</td>
#             </tr>
#             <tr>
#                         <th id="T_fb1269e8_f166_11eb_864b_d3fe1e01139flevel0_row1" class="row_heading level0 row1" >3</th>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow1_col0" class="data row1 col0" >326</td>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow1_col1" class="data row1 col1" >5090.164182</td>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow1_col2" class="data row1 col2" >18804</td>
#             </tr>
#             <tr>
#                         <th id="T_fb1269e8_f166_11eb_864b_d3fe1e01139flevel0_row2" class="row_heading level0 row2" >4</th>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow2_col0" class="data row2 col0" >326</td>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow2_col1" class="data row2 col1" >3998.861974</td>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow2_col2" class="data row2 col2" >18818</td>
#             </tr>
#             <tr>
#                         <th id="T_fb1269e8_f166_11eb_864b_d3fe1e01139flevel0_row3" class="row_heading level0 row3" >5</th>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow3_col0" class="data row3 col0" >357</td>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow3_col1" class="data row3 col1" >3968.153909</td>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow3_col2" class="data row3 col2" >18791</td>
#             </tr>
#             <tr>
#                         <th id="T_fb1269e8_f166_11eb_864b_d3fe1e01139flevel0_row4" class="row_heading level0 row4" >6</th>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow4_col0" class="data row4 col0" >338</td>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow4_col1" class="data row4 col1" >3840.991426</td>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow4_col2" class="data row4 col2" >18795</td>
#             </tr>
#             <tr>
#                         <th id="T_fb1269e8_f166_11eb_864b_d3fe1e01139flevel0_row5" class="row_heading level0 row5" >7</th>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow5_col0" class="data row5 col0" >336</td>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow5_col1" class="data row5 col1" >3264.062475</td>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow5_col2" class="data row5 col2" >18718</td>
#             </tr>
#             <tr>
#                         <th id="T_fb1269e8_f166_11eb_864b_d3fe1e01139flevel0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow6_col0" class="data row6 col0" >336</td>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow6_col1" class="data row6 col1" >2502.874388</td>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow6_col2" class="data row6 col2" >18445</td>
#             </tr>
#             <tr>
#                         <th id="T_fb1269e8_f166_11eb_864b_d3fe1e01139flevel0_row7" class="row_heading level0 row7" >9</th>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow7_col0" class="data row7 col0" >369</td>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow7_col1" class="data row7 col1" >2743.687289</td>
#                         <td id="T_fb1269e8_f166_11eb_864b_d3fe1e01139frow7_col2" class="data row7 col2" >18552</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# The inferences drawn from the above Exploratory Data analysis:
#
# Observation-1: (1).'Price' is the target variable while all others are the predictors. (2).The data set contains 26967 rows and 11 columns. (3).In the given dataset, there are 2 integer-type features 6 float-type features, and 3 object-type features, where 'price' is the target variable and all other are predector variable. (4).The first column ("Unnamed: 0") is an index of some sort or only a serial numbers, so we removed it.
#
# Observation-2: (1).In the given dataset, the the mean and median values do not differ a lot. (2).We can observe the minimum values of "x", "y", "z" to be zero. These are faulty values, as dimensionless or 2-dimensional diamonds are not possible. So we have to filter out those obvious faulty data entries. (3).There are three object data types: 'cut', 'color' and 'clarity'.
#
# Observation-3: There are 697 missing values in the depth column. There are some duplicate rows (34 out of 26,958 or 0.12 % of the total data), so in this case, we can drop the duplicated rows safely.
#
# Observation-4: There are significant amount of outliers, points that are far from the rest of the dataset, which will affect the outcome of our regression model. So, we have to treat the outliars. The distribution of some quantitative features such as "carat" and the target feature "price" are "right-skewed" heavily.
#
# Observation-5: Most features seem to correlate with the price of the diamond. The notable exception is "depth", which has a negligble correlation (~1%).

# %%
df[['carat','depth','table','x','y','z']].boxplot(figsize=(15,8), vert = 0)
#ns.boxplot(df[['carat','depth','table','x','y','z']] )
# Out:
# <AxesSubplot:>

# %%
# To decide on removing outliers or not, checking the linear distribution of price against independent variables

# %%
plt.figure(figsize=(8,5))
sns.regplot(x="price", y="carat", data=df, truncate=False, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
sns.despine(left = False, bottom = False)
plt.title('Price Vs Carat');

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(df['price'], df['carat'], color = 'darkblue')
sns.despine(left = False, bottom = False)
plt.title('Price Vs Carat');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(8,5))
sns.regplot(x="price", y="color", data=df, truncate=False, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
sns.despine(left = False, bottom = False)
plt.title('Price Vs Color');

# %%
plt.figure(figsize=(8,5))
sns.regplot(x="price", y="clarity", data=df, truncate=False, scatter_kws={"color": "blue"}, line_kws={"color": "red"})
sns.despine(left = False, bottom = False)
plt.title('Price Vs Clarity');

# %%
sns.scatterplot(df['price'], df['depth'], color = 'darkblue')
#sns.despine(left = False, bottom = False)
plt.title('Price Vs Depth');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(8,5))
sns.regplot(x="price", y="depth", data=df, truncate=False, scatter_kws={"color": "violet"}, line_kws={"color": "red"})
sns.despine(left = False, bottom = False)
plt.title('Price Vs Depth');

# %%
sns.scatterplot(df['price'], df['table'], color = 'darkblue')
sns.despine(left = False, bottom = False)
plt.title('Price Vs Table');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(8,5))
sns.regplot(x="price", y="table", data=df, truncate=False, scatter_kws={"color": "green"}, line_kws={"color": "red"})
sns.despine(left = False, bottom = False)
plt.title('Price Vs Table');

# %%
sns.scatterplot(df['price'], df['x'], color = 'darkblue')
sns.despine(left = False, bottom = False)
plt.title('Price Vs X');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(8,5))
sns.regplot(x="price", y="x", data=df, truncate=False, scatter_kws={"color": "orange"}, line_kws={"color": "darkblue"})
sns.despine(left = False, bottom = False)
plt.title('Price Vs x');

# %%
sns.scatterplot(df['price'], df['y'], color = 'darkblue')
sns.despine(left = False, bottom = False)
plt.title('Price Vs y');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(8,5))
sns.regplot(x="price", y="y", data=df, truncate=False, scatter_kws={"color": "orange"}, line_kws={"color": "darkblue"})
sns.despine(left = False, bottom = False)
plt.title('Price Vs y');

# %%
plt.figure(figsize=(8,5))
sns.regplot(x="price", y="z", data=df, truncate=False, scatter_kws={"color": "orange"}, line_kws={"color": "darkblue"})
sns.despine(left = False, bottom = False)
plt.title('Price Vs z');

# %%
# Removing outliers as outliers in price and carat can influence the linear equation towards the outliers

# %%
def remove_outlier(col):
    sorted(col)
    Q1,Q3=np.percentile(col,[25,75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %%
#cont=df[['carat','depth','table','x','y','z', 'price']].index
for column in df[['carat','depth','table','x','y','z', 'price']].columns:
    lr,ur=remove_outlier(df[column])
    df[column]=np.where(df[column]>ur,ur,df[column])
    df[column]=np.where(df[column]<lr,lr,df[column])

# %%
df[['carat','depth','table','x','y','z', 'price']].boxplot(figsize=(10,5), vert = 0);

# %%
plt.figure(figsize=(10,2))
plt.title('Carat without outliers',fontsize=12)
sns.boxplot(df['carat'] , orient = "h" , color = 'c');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,2))
plt.title('Depth without outliers',fontsize=12)
sns.boxplot(df['depth'] , orient = "h" , color = 'c');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,2))
plt.title('Table without outliers',fontsize=12)
sns.boxplot(df['table'] , orient = "h" , color = 'c');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,2))
plt.title('x without outliers',fontsize=12)
sns.boxplot(df['x'] , orient = "h" , color = 'c');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,2))
plt.title('y without outliers',fontsize=12)
sns.boxplot(df['y'] , orient = "h" , color = 'c');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,2))
plt.title('z without outliers',fontsize=12)
sns.boxplot(df['z'] , orient = "h" , color = 'c');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,2))
plt.title('Price without outliers',fontsize=12)
sns.boxplot(df['price'] , orient = "h" , color = 'c');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,2))
plt.title('Color without outliers',fontsize=12)
sns.boxplot(df['color'] , orient = "h" , color = 'c');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,2))
plt.title('Clarity without outliers',fontsize=12)
sns.boxplot(df['clarity'] , orient = "h" , color = 'c');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot(df['price'], df['carat'], color = 'green')
sns.despine(left = False, bottom = False)
plt.title('Price Vs Carat');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot(df['price'], df['x'], color = 'green')
sns.despine(left = False, bottom = False)
plt.title('Price Vs x');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Copy all the predictor variables into X dataframe
X = df.drop('price', axis=1)

# Copy target into the y dataframe. 
y = df[['price']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30 , random_state=25)

# %%
X_train.shape
# Out:
# (18841, 9)

# %%
X_test.shape
# Out:
# (8076, 9)

# %%
y_train.shape
# Out:
# (18841, 1)

# %%
y_test.shape
# Out:
# (8076, 1)

# %%
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
for idx, col_name in enumerate(X_train.columns):
    print("The coefficient for {} is {}".format(col_name, regression_model.coef_[0][idx]))
# Out:
# The coefficient for carat is 8892.062993696514
# The coefficient for cut is 104.55511505651437
# The coefficient for color is 267.76628197735033
# The coefficient for clarity is 434.1590655419247
# The coefficient for depth is -35.00943288069535
# The coefficient for table is -11.74099667010334
# The coefficient for x is -135.7609753524804
# The coefficient for y is -135.76097535248027
# The coefficient for z is -135.76097535248047

# %%
intercept = regression_model.intercept_[0]

print("The intercept for our model is {}".format(intercept))
# Out:
# The intercept for our model is -1554.9405604717886

# %%
rsquare = regression_model.score(X_test, y_test)
print("The R squared for our model is {}".format(rsquare))
# Out:
# The R squared for our model is 0.9272335173251998

# %%
predicted_train=regression_model.fit(X_train, y_train).predict(X_train)
RMSE_train = np.sqrt(mean_squared_error(y_train,predicted_train))
print("The Root Mean Squared Error for train {}".format(RMSE_train))
# Out:
# The Root Mean Squared Error for train 905.0572421449743

# %%
predicted_test=regression_model.fit(X_train, y_train).predict(X_test)
RMSE_test = np.sqrt(mean_squared_error(y_test,predicted_test))
print("The Root Mean Squared Error for test {}".format(RMSE_test))
# Out:
# The Root Mean Squared Error for test 931.9221883970914

# %% [markdown]
# ### Linear Regression using statsmodels

# %%
data_train = pd.concat([X_train, y_train], axis=1)
data_test=pd.concat([X_test,y_test],axis=1)
data_train.head()
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z    price
# 17417  0.320    4      2        9   61.9   54.2  4.38  4.38  4.38    783.0
# 22393  0.340    3      3        5   61.2   59.0  4.43  4.43  4.43    596.0
# 20522  2.025    2      1        5   62.5   58.0  8.09  8.09  8.09  11977.5
# 13908  0.510    4      3        5   62.4   56.0  5.11  5.11  5.11   1438.0
# 4534   0.320    3      2        5   62.7   58.0  4.35  4.35  4.35    605.0

# %%
expr = 'price ~ carat + cut + color + clarity + depth + table + x + y + z'

# %%
import statsmodels.formula.api as smf
lm1 = smf.ols(formula= expr, data = data_train).fit()
lm1.params
# Out:
# Intercept   -1554.940560
# carat        8892.062994
# cut           104.555115
# color         267.766282
# clarity       434.159066
# depth         -35.009433
# table         -11.740997
# x            -135.760975
# y            -135.760975
# z            -135.760975
# dtype: float64

# %%
print(lm1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.932
# Method:                 Least Squares   F-statistic:                 3.698e+04
# Date:                Sat, 31 Jul 2021   Prob (F-statistic):               0.00
# Time:                        00:23:59   Log-Likelihood:            -1.5500e+05
# No. Observations:               18841   AIC:                         3.100e+05
# Df Residuals:                   18833   BIC:                         3.101e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1554.9406    584.803     -2.659      0.008   -2701.206    -408.675
# carat       8892.0630     81.052    109.709      0.000    8733.195    9050.931
# cut          104.5551      7.229     14.464      0.000      90.386     118.724
# color        267.7663      4.101     65.290      0.000     259.728     275.805
# clarity      434.1591      4.484     96.834      0.000     425.371     442.947
# depth        -35.0094      6.434     -5.441      0.000     -47.622     -22.397
# table        -11.7410      3.835     -3.062      0.002     -19.257      -4.225
# x           -135.7610     11.154    -12.171      0.000    -157.624    -113.898
# y           -135.7610     11.154    -12.171      0.000    -157.624    -113.898
# z           -135.7610     11.154    -12.171      0.000    -157.624    -113.898
# ==============================================================================
# Omnibus:                     2621.541   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11686.503
# Skew:                           0.619   Prob(JB):                         0.00
# Kurtosis:                       6.654   Cond. No.                     5.18e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.1e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
#The overall P value is less than alpha, so rejecting H0 and accepting Ha that atleast 1 regression co-efficient is not 0. Here all regression co-efficients are not 0
#The P value of all the independent variables are less than alpha, means all the variables are statistically significant in deciding Price
#The model can explain 93.2%of the variance in price as both the R squared and adjusted R squared values are .932

# %%
#mse = np.mean((lm1.predict(data_train.drop('price',axis=1))-data_train['price'])**2)
MSE_train = np.mean((lm1.predict(X_train)- y_train['price'])**2)

# %%
RMSE_train = np.sqrt(MSE_train)
print("The Root Mean Squared Error for train {}".format(RMSE_train))
# Out:
# The Root Mean Squared Error for train 905.0572421449742

# %%
np.sqrt(lm1.mse_resid) #same as above but another way
# Out:
# 905.2494496846291

# %%
# Prediction on Test data
y_pred = lm1.predict(X_test)

# %%
sns.scatterplot(x=y_test['price'], y=y_pred, color = 'purple')
sns.despine(left = False, bottom = False)
plt.title('Test Label Vs Predicted Label');

# %%
#test for normality of residuals
import statsmodels.api as sm
def draw_pp_plot( model, title ):
    probplot = sm.ProbPlot(model.resid);
    plt.figure( figsize = (8,6));
    probplot.ppplot(line='45');
    plt.title(title);
    plt.show();

# %%
draw_pp_plot(lm1,"Test for normality of residuals");

# %%
def get_standardized_values (vals):
    return (vals-vals.mean())/vals.std()

# %%
def plot_resid_fitted(fitted, resid, title):
    sns.scatterplot(x=get_standardized_values( fitted ),
                    y=get_standardized_values( resid ),
                    color = 'darkblue')
    sns.despine(left = False, bottom = False) 
    plt.xlabel("Standardized predicted values")
    plt.ylabel("standardized residual values")
    plt.title(title);

# %%
plot_resid_fitted(lm1.fittedvalues,
                  lm1.resid,
                  "Residual plot to test Homoscedasticity")

# %%
for i,j in np.array(lm1.params.reset_index()):
    print('({}) * {} +'.format(round(j,2),i),end=' ')
# Out:
# (-1554.94) * Intercept + (8892.06) * carat + (104.56) * cut + (267.77) * color + (434.16) * clarity + (-35.01) * depth + (-11.74) * table + (-135.76) * x + (-135.76) * y + (-135.76) * z +

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def get_vif_factors(X):
    X_m = np.asmatrix(X)
    vif = [variance_inflation_factor(X_m,i) for i in range (X_m.shape[1])]
    vif_factors = pd.DataFrame()
    vif_factors['column']= X.columns
    vif_factors['VIF'] = vif
    return vif_factors

# %%
vif_factors = get_vif_factors(X)
vif_factors
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#     column         VIF
# 0    carat  107.749383
# 1      cut    8.843211
# 2    color    5.535496
# 3  clarity   12.451131
# 4    depth  574.800463
# 5    table  577.205320
# 6        x         inf
# 7        y         inf
# 8        z         inf

# %%
vif_factors = get_vif_factors(X[['carat','cut','color','clarity','depth','table','x']])
vif_factors
# Out:
#     column         VIF
# 0    carat  107.749383
# 1      cut    8.843211
# 2    color    5.535496
# 3  clarity   12.451131
# 4    depth  574.800463
# 5    table  577.205320
# 6        x  738.541750

# %%
############# ITERATION 2 ##########

# %%
## trying to improve the model

# %%
y_train_sqrt = np.sqrt(y_train['price']) # transforming the response variable

# %%
data_train2 = pd.concat([X_train, y_train_sqrt], axis=1)
data_test2 = pd.concat([X_test,y_test],axis=1)
data_train2['volume']= data_train2['x']*data_train2['y']*data_train2['z']
data_test2['volume']= data_test2['x']*data_test2['y']*data_test2['z']
data_train2.head(10)
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z       price  \
# 17417  0.320    4      2        9   61.9   54.2  4.38  4.38  4.38   27.982137
# 22393  0.340    3      3        5   61.2   59.0  4.43  4.43  4.43   24.413111
# 20522  2.025    2      1        5   62.5   58.0  8.09  8.09  8.09  109.441765
# 13908  0.510    4      3        5   62.4   56.0  5.11  5.11  5.11   37.920970
# 4534   0.320    3      2        5   62.7   58.0  4.35  4.35  4.35   24.596748
# 8764   0.750    4      3        7   61.3   55.0  5.85  5.85  5.85   59.371710
# 23555  0.800    2      4        6   63.6   57.0  5.82  5.82  5.82   59.657355
# 18605  2.020    4      1        3   61.7   57.0  8.05  8.05  8.05  109.441765
# 2896   0.430    3      3        4   62.7   56.0  4.83  4.83  4.83   31.112698
# 5993   1.070    4      3        3   62.4   57.0  6.56  6.56  6.56   66.475559
#
#            volume
# 17417   84.027672
# 22393   86.938307
# 20522  529.475129
# 13908  133.432831
# 4534    82.312875
# 8764   200.201625
# 23555  197.137368
# 18605  521.660125
# 2896   112.678587
# 5993   282.300416

# %%
vif_factors = get_vif_factors(data_train2[['carat','cut','color','clarity','x','volume']])
vif_factors
# Out:
#     column         VIF
# 0    carat  319.081330
# 1      cut    8.423378
# 2    color    5.517011
# 3  clarity   11.330653
# 4        x   72.369493
# 5   volume  285.472354

# %%
expr = 'price ~ carat + cut + color + clarity + volume + x'

# %%
import statsmodels.formula.api as smf
lm2 = smf.ols(formula= expr, data = data_train2).fit()
lm2.params
# Out:
# Intercept   -89.080297
# carat        49.669038
# cut           0.737454
# color         1.987285
# clarity       3.257709
# volume       -0.115795
# x            18.077889
# dtype: float64

# %%
print(lm2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.963
# Method:                 Least Squares   F-statistic:                 8.234e+04
# Date:                Sat, 31 Jul 2021   Prob (F-statistic):               0.00
# Time:                        01:03:29   Log-Likelihood:                -57661.
# No. Observations:               18841   AIC:                         1.153e+05
# Df Residuals:                   18834   BIC:                         1.154e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -89.0803      0.770   -115.694      0.000     -90.590     -87.571
# carat         49.6690      0.773     64.252      0.000      48.154      51.184
# cut            0.7375      0.035     20.949      0.000       0.668       0.806
# color          1.9873      0.023     85.000      0.000       1.941       2.033
# clarity        3.2577      0.025    128.093      0.000       3.208       3.308
# volume        -0.1158      0.003    -43.574      0.000      -0.121      -0.111
# x             18.0779      0.187     96.461      0.000      17.711      18.445
# ==============================================================================
# Omnibus:                     1141.599   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3942.711
# Skew:                           0.240   Prob(JB):                         0.00
# Kurtosis:                       5.189   Cond. No.                     5.88e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.88e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
draw_pp_plot(lm2,"Test for normality of residuals")

# %%
plot_resid_fitted(lm2.fittedvalues,
                  lm2.resid,
                  "Residual plot to test Homoscedasticity")

# %%
for i,j in np.array(lm1.params.reset_index()):
    print('({}) * {} +'.format(round(j,2),i),end=' ')
# Out:
# (-1554.94) * Intercept + (8892.06) * carat + (104.56) * cut + (267.77) * color + (434.16) * clarity + (-35.01) * depth + (-11.74) * table + (-135.76) * x + (-135.76) * y + (-135.76) * z +

# %%
y_pred_train = lm2.predict(data_train2.drop('price',axis=1))

# %%
rmse_train = np.sqrt(mean_squared_error(data_train2['price'],y_pred_train))
print("The Root Mean Squared Error for train {}".format(rmse_train))
# Out:
# The Root Mean Squared Error for train 5.1627285575168775

# %%
# Prediction on Test data. taking the square of Y as test price was not transformed
y_pred_test = np.power(lm2.predict(data_test2.drop('price',axis=1)),2)

# %%
#mse_test = np.mean((y_pred-data_test2['price'])**2)

# %%
rmse_test = np.sqrt(mean_squared_error(data_test2['price'],y_pred_test))
print("The Root Mean Squared Error for test {}".format(rmse_test))
# Out:
# The Root Mean Squared Error for test 816.7544672187873

# %%
rsquare = metrics.r2_score(y_pred_test, data_test2['price'])
print("The R squared for our model is {}".format(rsquare))
# Out:
# The R squared for our model is 0.9381834925086128

# %%
sns.scatterplot(x=y_test['price'], y=y_pred_test, color = 'purple')
sns.despine(left = False, bottom = False)
plt.title('Test Label Vs Predicted Label');

# %%
############### ITERATION 3 ###################

# %%
## attempting scaling on the data

# %%
from scipy.stats import zscore

X_train['volume']=X_train['x']*X_train['y']*X_train['z']
X_test['volume']=X_test['x']*X_test['y']*X_test['z']
X_train_scaled  = X_train.apply(zscore)
X_test_scaled = X_test.apply(zscore)
y_train_scaled = y_train.apply(zscore)
y_test_scaled = y_test.apply(zscore)
X_train_scaled = X_train_scaled.drop('y', axis=1)
X_train_scaled = X_train_scaled.drop('z', axis=1)
X_train_scaled = X_train_scaled.drop('depth', axis=1)
X_train_scaled = X_train_scaled.drop('table', axis=1)
X_test_scaled = X_test_scaled.drop('y', axis=1)
X_test_scaled = X_test_scaled.drop('z', axis=1)
X_test_scaled = X_test_scaled.drop('depth', axis=1)
X_test_scaled = X_test_scaled.drop('table', axis=1)
# Out:
# <ipython-input-422-a38dbf629ad4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['volume']=X_train['x']*X_train['y']*X_train['z']
# <ipython-input-422-a38dbf629ad4>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['volume']=X_test['x']*X_test['y']*X_test['z']

# %%
X_train_scaled
# Out:
#           carat       cut     color   clarity         x    volume
# 17417 -1.020850  0.977964 -0.820537  2.418378 -1.195297 -1.006207
# 22393 -0.977707  0.078398 -0.233072 -0.026832 -1.150990 -0.983049
# 20522  2.657119 -0.821169 -1.408002 -0.026832  2.092274  2.538018
# 13908 -0.610988  0.977964 -0.233072 -0.026832 -0.548417 -0.613113
# 4534  -1.020850  0.078398 -0.820537 -0.026832 -1.221881 -1.019851
# ...         ...       ...       ...       ...       ...       ...
# 24875 -0.999278  0.977964  0.354394  2.418378 -1.115545 -0.964141
# 2934  -1.063993  0.078398 -1.408002  0.584470 -1.177575 -0.997007
# 26817  1.157888  0.078398  0.941859 -1.249437  1.117522  1.042640
# 6622  -0.179555  0.977964  0.941859 -0.638135  0.054157 -0.130375
# 24938 -1.128708  0.977964  0.941859  1.807075 -1.363664 -1.089493
#
# [18841 rows x 6 columns]

# %%
regression_model = LinearRegression()
regression_model.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression()

# %%
for idx, col_name in enumerate(X_train_scaled.columns):
    print("The coefficient for {} is {}".format(col_name, regression_model.coef_[0][idx]))
# Out:
# The coefficient for carat is 1.1681515994920995
# The coefficient for cut is 0.03886382903552191
# The coefficient for color is 0.13157391915601888
# The coefficient for clarity is 0.20558188978401648
# The coefficient for x is -0.11896829912319391
# The coefficient for volume is 0.004460347899608847

# %%
intercept = regression_model.intercept_[0]

print("The intercept for our model is {}".format(intercept))
# Out:
# The intercept for our model is 1.3274571197786881e-16

# %%
regression_model.score(X_test_scaled, y_test_scaled)
# Out:
# 0.9268612878102879

# %%
regression_model.score(X_train_scaled, y_train_scaled)
# Out:
# 0.9320805679389167

# %%
mse = np.mean((regression_model.predict(X_train_scaled)-y_train_scaled)**2)

# %%
import math

math.sqrt(mse)
# Out:
# 0.2606135684516118

# %%
mse = np.mean((regression_model.predict(X_test_scaled)-y_test_scaled)**2)

# %%
math.sqrt(mse)
# Out:
# 0.2704416983190874

# %%
data_train3 = pd.concat([X_train_scaled, y_train_scaled], axis=1)
data_test3 = pd.concat([X_test_scaled,y_test_scaled],axis=1)

data_train3.describe().T
# Out:
#            count          mean       std       min       25%       50%  \
# carat    18841.0 -1.394305e-16  1.000027 -1.279710 -0.848277 -0.201127
# cut      18841.0 -9.571335e-16  1.000027 -2.620303 -0.821169  0.078398
# color    18841.0 -3.684166e-16  1.000027 -1.995467 -0.820537 -0.233072
# clarity  18841.0  1.387116e-16  1.000027 -1.860740 -0.638135 -0.026832
# x        18841.0 -4.254922e-16  1.000027 -1.771287 -0.902872 -0.034457
# volume   18841.0 -2.678065e-16  1.000027 -1.261872 -0.843421 -0.209022
# price    18841.0 -2.006722e-16  1.000027 -0.980376 -0.802275 -0.392271
#
#               75%       max
# carat    0.553881  2.657119
# cut      0.977964  0.977964
# color    0.941859  1.529324
# clarity  0.584470  2.418378
# x        0.727622  3.173362
# volume   0.561104  4.745797
# price    0.463993  2.372026

# %%
expr = 'price ~ carat + cut + color + clarity + volume'

# %%
lm3 = smf.ols(formula= expr, data = data_train3).fit()
lm3.params
# Out:
# Intercept    6.938894e-18
# carat        1.088202e+00
# cut          3.845729e-02
# color        1.303271e-01
# clarity      2.092927e-01
# volume      -3.187305e-02
# dtype: float64

# %%
print (lm3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.932
# Method:                 Least Squares   F-statistic:                 5.133e+04
# Date:                Fri, 30 Jul 2021   Prob (F-statistic):               0.00
# Time:                        23:44:59   Log-Likelihood:                -1460.3
# No. Observations:               18841   AIC:                             2933.
# Df Residuals:                   18835   BIC:                             2980.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   6.939e-18      0.002   3.64e-15      1.000      -0.004       0.004
# carat          1.0882      0.017     65.317      0.000       1.056       1.121
# cut            0.0385      0.002     19.408      0.000       0.035       0.042
# color          0.1303      0.002     64.761      0.000       0.126       0.134
# clarity        0.2093      0.002    100.605      0.000       0.205       0.213
# volume        -0.0319      0.017     -1.921      0.055      -0.064       0.001
# ==============================================================================
# Omnibus:                     2412.435   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8773.215
# Skew:                           0.623   Prob(JB):                         0.00
# Kurtosis:                       6.102   Cond. No.                         18.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
draw_pp_plot(lm3,"Test for normality of residuals");

# %%
plot_resid_fitted(lm3.fittedvalues,
                  lm3.resid,
                  "Residual plot to test Homoscedasticity")

# %%
y_pred_train = lm3.predict(data_train3.drop('price',axis=1))
rmse_train = np.sqrt(mean_squared_error(data_train3['price'],y_pred_train))
print("The Root Mean Squared Error for train {}".format(rmse_train))
# Out:
# The Root Mean Squared Error for train 0.2614712946761062

# %%
y_pred_test = lm3.predict(data_test3.drop('price',axis=1))

# %%
rmse_test = np.sqrt(mean_squared_error(data_test3['price'],y_pred_test))
print("The Root Mean Squared Error for test {}".format(rmse_test))
# Out:
# The Root Mean Squared Error for test 0.2708579944270211

# %%
rsquare = metrics.r2_score(y_pred_test, data_test3['price'])
print("The R squared for our model is {}".format(rsquare))
# Out:
# The R squared for our model is 0.9212153184912829

# %%
sns.scatterplot(x=y_test['price'], y=y_pred_test, color = 'purple')
sns.despine(left = False, bottom = False)
plt.title('Test Label Vs Predicted Label');
